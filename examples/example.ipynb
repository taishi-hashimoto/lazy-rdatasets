# %% [markdown]
# ## Example usage of lazy-rdatasets
#
# ### List all available datasets

# %%
from lazyrdatasets import LazyRdatasets

rd = LazyRdatasets()
rd
# Out:
# Rdatasets(len=3499)

# %% [markdown]
# ### Finding datasets
#
# #### 1. Exact match on the package and item names
#
# This is almost the same as [statsmodels.datasets.get_rdatasets](https://www.statsmodels.org/stable/datasets/statsmodels.datasets.get_rdataset.html).

# %%
rd = LazyRdatasets.find(package="palmerpenguins", item="penguins", exact=True)
rd
# Out:
# Rdatasets(len=1)

# %% [markdown]
# #### 2. Search a string in the title of datasets
#
# Find datasets that have "penguin" in their title:

# %%
rd = LazyRdatasets.find(title="penguin")
rd
# Out:
# Rdatasets(len=7)

# %% [markdown]
# #### 3. Filtering datasets that contains particular types of variables
#
# Find datasets that have categorical variables:

# %%
rd = LazyRdatasets.find(categorical=True)
rd
# Out:
# Rdatasets(len=2437)

# %% [markdown]
# Find datasets that have only one numeric variables with more than 99 samples:

# %%
rd = LazyRdatasets.find(numeric=True, nmin=100, pmax=1)
rd
# Out:
# Rdatasets(len=52)

# %% [markdown]
# ### Getting a single dataset from Rdatasets
#
# Below, `rd` is the output of the following code block:

# %%
rd = LazyRdatasets.find(title="penguin")

# %% [markdown]
# #### 1. Show the list of datasets that matched the conditions

# %%
rd  # On jupyter, this will show the same result as below.
rd.catalog  # Show the repr of DataFrame
# Out:
#              Package                     Item  \
# 567       bayesrules           penguins_bayes
# 1031        datasets                 penguins
# 1032        datasets  penguins_raw (penguins)
# 1699         heplots                     peng
# 2152       modeldata                 penguins
# 2595  palmerpenguins                 penguins
# 2596  palmerpenguins  penguins_raw (penguins)
#
#                                                   Title  Rows  Cols  n_binary  \
# 567                                       Penguins Data   344     9         2
# 1031  Measurements of Penguins near Palmer Station, ...   344     8         1
# 1032  Measurements of Penguins near Palmer Station, ...   344    17         2
# 1699  Size measurements for penguins near Palmer Sta...   333     8         1
# 2152                        Palmer Station penguin data   344     7         1
# 2595  Size measurements for adult foraging penguins ...   344     8         1
# 2596  Penguin size, clutch, and blood isotope data f...   344    17         2
#
#       n_character  n_factor  n_logical  n_numeric  \
# 567             0         4          0          5
# 1031            0         3          0          5
# 1032            9         0          0          7
# 1699            0         3          0          5
# 2152            0         3          0          4
# 2595            0         3          0          5
# 2596            9         0          0          7
#
#                                                     CSV  \
# 567   https://vincentarelbundock.github.io/Rdatasets...
# 1031  https://vincentarelbundock.github.io/Rdatasets...
# 1032  https://vincentarelbundock.github.io/Rdatasets...
# 1699  https://vincentarelbundock.github.io/Rdatasets...
# 2152  https://vincentarelbundock.github.io/Rdatasets...
# 2595  https://vincentarelbundock.github.io/Rdatasets...
# 2596  https://vincentarelbundock.github.io/Rdatasets...
#
#                                                     Doc
# 567   https://vincentarelbundock.github.io/Rdatasets...
# 1031  https://vincentarelbundock.github.io/Rdatasets...
# 1032  https://vincentarelbundock.github.io/Rdatasets...
# 1699  https://vincentarelbundock.github.io/Rdatasets...
# 2152  https://vincentarelbundock.github.io/Rdatasets...
# 2595  https://vincentarelbundock.github.io/Rdatasets...
# 2596  https://vincentarelbundock.github.io/Rdatasets...

# %% [markdown]
# #### 2. Pick the first dataset in the list

# %%
rd.first
# Out:
# #️⃣ Index  : 567
# 📦 Package: bayesrules
# 📄 Item   : penguins_bayes
# 📚 Title  : Penguins Data
# 📐 Shape  : (344, 10)
#   ⚖️ Binary   : 2
#   🔤 Character: 0
#   🧮 Factor   : 4
#   🔘 Logical  : 0
#   🔢 Numeric  : 5
# 🔗 CSV: https://vincentarelbundock.github.io/Rdatasets/csv/bayesrules/penguins_bayes.csv
# 🔗 Doc: https://vincentarelbundock.github.io/Rdatasets/doc/bayesrules/penguins_bayes.html

# %% [markdown]
# #### 3. Acceess by `Index` and position in the catalog

# %%
rd[2595]  # Get the Dataset with its index 2595 (pandas.DataFrame.loc), or ...
# Out:
# #️⃣ Index  : 2595
# 📦 Package: palmerpenguins
# 📄 Item   : penguins
# 📚 Title  : Size measurements for adult foraging penguins near Palmer Station, Antarctica
# 📐 Shape  : (344, 9)
#   ⚖️ Binary   : 1
#   🔤 Character: 0
#   🧮 Factor   : 3
#   🔘 Logical  : 0
#   🔢 Numeric  : 5
# 🔗 CSV: https://vincentarelbundock.github.io/Rdatasets/csv/palmerpenguins/penguins.csv
# 🔗 Doc: https://vincentarelbundock.github.io/Rdatasets/doc/palmerpenguins/penguins.html

# %%
rd.at(5)  # Get the Dataset at position 3 in the catalog (pandas.DataFrame.iloc)
# Out:
# #️⃣ Index  : 2595
# 📦 Package: palmerpenguins
# 📄 Item   : penguins
# 📚 Title  : Size measurements for adult foraging penguins near Palmer Station, Antarctica
# 📐 Shape  : (344, 9)
#   ⚖️ Binary   : 1
#   🔤 Character: 0
#   🧮 Factor   : 3
#   🔘 Logical  : 0
#   🔢 Numeric  : 5
# 🔗 CSV: https://vincentarelbundock.github.io/Rdatasets/csv/palmerpenguins/penguins.csv
# 🔗 Doc: https://vincentarelbundock.github.io/Rdatasets/doc/palmerpenguins/penguins.html

# %% [markdown]
# ### Getting the dataframe

# %%
ds = rd[2595]
ds.data  # -> pandas.DataFrame
# Out:
#      rownames    species     island  bill_length_mm  bill_depth_mm  \
# 0           1     Adelie  Torgersen            39.1           18.7
# 1           2     Adelie  Torgersen            39.5           17.4
# 2           3     Adelie  Torgersen            40.3           18.0
# 3           4     Adelie  Torgersen             NaN            NaN
# 4           5     Adelie  Torgersen            36.7           19.3
# ..        ...        ...        ...             ...            ...
# 339       340  Chinstrap      Dream            55.8           19.8
# 340       341  Chinstrap      Dream            43.5           18.1
# 341       342  Chinstrap      Dream            49.6           18.2
# 342       343  Chinstrap      Dream            50.8           19.0
# 343       344  Chinstrap      Dream            50.2           18.7
#
#      flipper_length_mm  body_mass_g     sex  year
# 0                181.0       3750.0    male  2007
# 1                186.0       3800.0  female  2007
# 2                195.0       3250.0  female  2007
# 3                  NaN          NaN     NaN  2007
# 4                193.0       3450.0  female  2007
# ..                 ...          ...     ...   ...
# 339              207.0       4000.0    male  2009
# 340              202.0       3400.0  female  2009
# 341              193.0       3775.0    male  2009
# 342              210.0       4100.0    male  2009
# 343              198.0       3775.0  female  2009
#
# [344 rows x 9 columns]

# %% [markdown]
# ### Quicklook
#
# Selected dataset can be easily quicklooked by:

# %%
ds.quicklook()

# %% [markdown]
# This is of course not the best visualization, but might be helpful to get an overview of the dataset.
